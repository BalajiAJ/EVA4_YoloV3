# %%
# !git clone https://github.com/BalajiAJ/Yolo-V3.git
# Out:
# Cloning into 'Yolo-V3'...
# remote: Enumerating objects: 1432, done.
# remote: Counting objects: 100% (1432/1432), done.
# remote: Compressing objects: 100% (1401/1401), done.
# remote: Total 1432 (delta 1), reused 1432 (delta 1), pack-reused 0
# Receiving objects: 100% (1432/1432), 868.71 MiB | 13.21 MiB/s, done.
# Resolving deltas: 100% (1/1), done.
# Checking out files: 100% (1416/1416), done.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.5.1+cu101 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15079MB, multi_processor_count=40)

# %%
ls
# Out:
# gdrive/  sample_data/  Yolo-V3/

# %%
cd YoloV3/
# Out:
# /content/YoloV3

# %%
# !ls
# Out:
#  cfg	     __pycache__    test_batch0.png   'ubdivisions=1'
#  data	     README.md	    test.py	       utils
#  detect.py   results.json   ting	       vim.exe.stackdump
#  models.py   results.png    train_batch0.png   weights
#  output      results.txt    train.py

# %%
# !python train.py --data data/smalcoco/smalcoco.data --batch 3 --cache --epochs 3 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=3, bucket='', cache_images=True, cfg='cfg/yolov3-spp.cfg', data='data/smalcoco/smalcoco.data', device='', epochs=3, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# 2020-07-11 13:38:21.739421: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.29987e+07 parameters, 6.29987e+07 gradients
# Caching labels (20 found, 0 missing, 0 empty, 0 duplicate, for 20 images): 100% 20/20 [00:00<00:00, 6541.85it/s]
# Caching images (0.0GB): 100% 20/20 [00:00<00:00, 105.93it/s]
# ...

# %%
# !python train.py --data data/customdata/custom.data --batch 10 --cache --cfg cfg/yolov3-custom.cfg --epochs 50 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=10, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=50, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# 2020-07-11 13:41:06.094226: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# Caching labels (664 found, 0 missing, 1 empty, 0 duplicate, for 665 images): 100% 665/665 [00:00<00:00, 9527.59it/s]
# Caching images (0.3GB): 100% 665/665 [00:13<00:00, 48.65it/s]
# Reading image shapes: 100% 665/665 [00:12<00:00, 55.08it/s]
# ...

# %%
# !python detect.py --conf-thres 0.1 --output out_out
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='out_out', save_txt=False, source='data/customdata/images', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# image 1/665 data/customdata/images/img001.jpg: 320x512 1 footballs, Done. (0.033s)
# image 2/665 data/customdata/images/img002.jpg: 320x512 1 footballs, Done. (0.027s)
# image 3/665 data/customdata/images/img003.jpg: 320x512 1 footballs, Done. (0.027s)
# image 4/665 data/customdata/images/img004.jpg: 320x512 1 footballs, Done. (0.027s)
# image 5/665 data/customdata/images/img005.jpg: 320x512 1 footballs, Done. (0.027s)
# image 6/665 data/customdata/images/img006.jpg: 320x512 1 footballs, Done. (0.027s)
# ...

# %%
Image(filename='out_out/img200.jpg', width=600)

# %%
Image(filename='out_out/img222.jpg', width=600)

# %%
from google.colab import files
files.download("out_out/img001.jpg")

# %%
ls
# Out:
#  cfg/        output/        results.txt       train_batch0.png    weights/
#  data/       __pycache__/   runs/             train.py
#  detect.py   README.md      test_batch0.png  'ubdivisions=1'
#  models.py   results.json   test.py           utils/
#  out_out/    results.png    ting              vim.exe.stackdump

# %%
# !zip -r /content/file.zip /content/out_out
# Out:
# 	zip warning: name not matched: /content/out_out
#
# zip error: Nothing to do! (try: zip -r /content/file.zip . -i /content/out_out)

# %%
# !zip -r ./out_out.zip ./out_out/
# Out:
#   adding: out_out/ (stored 0%)
#   adding: out_out/img535.jpg (deflated 1%)
#   adding: out_out/img406.jpg (deflated 0%)
#   adding: out_out/img232.jpg (deflated 0%)
#   adding: out_out/img311.jpg (deflated 0%)
#   adding: out_out/img236.jpg (deflated 1%)
#   adding: out_out/img350.jpg (deflated 0%)
#   adding: out_out/img437.jpg (deflated 0%)
#   adding: out_out/img268.jpg (deflated 0%)
#   adding: out_out/img527.jpg (deflated 1%)
#   adding: out_out/img180.jpg (deflated 0%)
#   adding: out_out/img524.jpg (deflated 1%)
#   adding: out_out/img099.jpg (deflated 1%)
#   adding: out_out/img395.jpg (deflated 0%)
#   adding: out_out/img118.jpg (deflated 0%)
#   adding: out_out/img158.jpg (deflated 1%)
#   adding: out_out/img199.jpg (deflated 0%)
#   adding: out_out/img052.jpg (deflated 0%)
#   adding: out_out/img494.jpg (deflated 1%)
#   adding: out_out/img421.jpg (deflated 0%)
#   adding: out_out/img203.jpg (deflated 0%)
#   adding: out_out/img039.jpg (deflated 1%)
# ...

# %%
ls
# Out:
#  cfg/          output/        runs/             'ubdivisions=1'
#  data/         __pycache__/   test_batch0.png    utils/
#  detect.py     README.md      test.py            vim.exe.stackdump
#  models.py     results.json   ting               weights/
#  out_out/      results.png    train_batch0.png
#  out_out.zip   results.txt    train.py

# %%
files.download("out_out.zip")
